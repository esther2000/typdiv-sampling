# %%
import pandas as pd
from pathlib import Path
import altair as alt

# Frame = all languages in GB
# k = range from 5 to 500, steps of 5
# distances = all language in GB
df = pd.read_csv("experiments/experiment-5-500-5-both-metrics.csv")

plot = (
    alt.Chart(df)
    .mark_circle()
    .encode(
        x=alt.X(
            "k",
            title="Sample size (k)",
        ),
        y=alt.Y(
            "entropy_without_missing",
            # scale=alt.Scale(domain=[1.0, 1.14]),
            title="Entropy",
        ),
        color=alt.Color('method').scale(range=['steelblue', '#7D3C98', 'chartreuse', '#F4D03F', 'red', '#D35400', ])
    )
    .configure_axis(labelFontSize=12, labelFont="serif", titleFontSize=16, titleFont="serif")
)
plot
# Out:
# alt.Chart(...)

# %%
plot2 = (
    alt.Chart(df[df['k'] <= 100])
    .mark_circle()
    .encode(
        x=alt.X(
            "k",
            title="Sample size (k)",
        ),
        y=alt.Y(
            "entropy_without_missing",
            # scale=alt.Scale(domain=[0, 3]),
            title="Entropy",
        ),
        color=alt.Color('method').scale(range=['steelblue', '#7D3C98', 'chartreuse', '#F4D03F', 'red', '#D35400', ])
    )
    .configure_axis(labelFontSize=12, labelFont="serif", titleFontSize=16, titleFont="serif")
)
plot2
# Out:
# alt.Chart(...)

# %%
plot.save("plots/entropy-by-k-plot.pdf")
plot2.save("plots/entropy-by-k-peak-plot.pdf")
